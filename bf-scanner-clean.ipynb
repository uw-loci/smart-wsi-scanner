# %% [markdown]
# # SmartPath: Intelligent Multimodal Acquisition for Histopathological Whole Slide Scanning

# %% [markdown]
# Quick Instructions:
# How to run a cell (section)?
# Click blank space in front of the '...' below each section and hit Shift+Return, or click the "run the selected cells and advance" botton in the top menu

# %% [markdown]
# ## 1. System configuration
# Note: wait for "System configured!" Message

# %%
import os, glob, shutil, sys, copy, time, json, copy, subprocess, math, warnings
from IPython import display
from tqdm import tqdm
from pycromanager import Acquisition, Bridge, Dataset, multi_d_acquisition_events
from skimage import io, img_as_ubyte, img_as_float, img_as_uint, color, transform, exposure
from skimage.filters import threshold_mean, sobel
from skimage.measure import shannon_entropy
from skimage.util import view_as_windows, crop
import imagej
import json
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from scipy.stats import norm
import scipy as sp
from shapely.geometry import mapping, shape
from tkinter import filedialog

from acquisitions import *
from image_utils import *
from enhancer import Enhancer
from predictor import Predictor

os.environ['_JAVA_OPTIONS']="-Xmx12g"
warnings.filterwarnings('ignore')
Image.MAX_IMAGE_PIXELS = None

def config_sys(config):
    if config["exposure-level"]=="low":
        config["lsm-scan-rate"] = '500000.0000'
        config["lsm-pc-power"] = 0.3
        config["lsm-pmt-gain"] = 0.35
    if config["exposure-level"]=="mid":
        config["lsm-scan-rate"] = '400000.0000'
        config["lsm-pc-power"] = 0.4
        config["lsm-pmt-gain"] = 0.4
    if config["exposure-level"]=="high":
        config["lsm-scan-rate"] = '250000.0000'
        config["lsm-pc-power"] = 0.425
        config["lsm-pmt-gain"] = 0.425
    if config["exposure-level"]=="extreme":
        config["lsm-scan-rate"] = '200000.0000'
        config["lsm-pc-power"] = 0.45
        config["lsm-pmt-gain"] = 0.45
    config["pixel-size-shg"] = config["pixel-size-shg-base"] * 256 / config["lsm-resolution"]
    if config["enhancement-type"] is not None:
        config["enhancer"] = Enhancer(config)
    if config["classifier"] is not None:
        config["predictor"] = Predictor(config)
    return config

def whole_slide_scan(config, core=None, save_path=None, acq_name=None, position_list=None, mag='4x', mda=False, z_stack=False, z_center=None, sample_depth=20, z_step=4, estimate_background=False, background_image=None, focus_dive=False):
    if mda == True:
        if position_list.shape[1] == 3:
            if z_stack:
                with Acquisition(save_path, acq_name, lsm_process_fn(config)) as acq:
                    events = multi_d_acquisition_events(xyz_positions=position_list.reshape(-1, 3), z_start=-int(sample_depth/2), z_end=int(sample_depth/2), z_step=z_step)
                    acq.acquire(events)      
            else:
                with Acquisition(save_path, acq_name) as acq:
                    events = multi_d_acquisition_events(xyz_positions=position_list.reshape(-1, 3))
                    acq.acquire(events)
        else:
            if z_center is None:
                z_center = config["Z-stage-laser"]
            if z_stack:
                with Acquisition(save_path, acq_name) as acq:
                    events = multi_d_acquisition_events(xy_positions=position_list.reshape(-1, 2), z_start=-int(sample_depth/2) + z_center, z_end=int(sample_depth/2) + z_center, z_step=z_step)
                    acq.acquire(events)
            else:
                with Acquisition(save_path, acq_name) as acq:
                    events = multi_d_acquisition_events(xy_positions=position_list.reshape(-1, 2))
                    acq.acquire(events)
    else:
        fig = plt.figure(figsize=(8, 6))
        plt.axis("off")
        show = plt.imshow(np.zeros((config["camera-resolution"][1], config["camera-resolution"][0])))
        acq_id = len(glob.glob(os.path.join(save_path, acq_name+"*")))
        acq_path = os.path.join(save_path, acq_name+"_{}".format(acq_id+1))
        os.makedirs(acq_path, exist_ok=True)
        redive_flag = True
        bg_flag = False
        first_tile = True
        use_autofocus = True
        record_z = []
        if estimate_background:
            sum_img = np.zeros((config["camera-resolution"][1], config["camera-resolution"][0], 3))
            sum_count = 0
        if background_image is not None:
            bg_img = white_balance(copy.deepcopy(background_image), copy.deepcopy(background_image))
        if position_list.shape[1] == 3:
            tile_count = 0
            z_positions=np.ones(position_list.shape[0]) * core.get_position()
            core.set_focus_device(config["focus-device"])
            autofocus_count = 0
            for pos in range(position_list.shape[0]):
                z_pos = position_list[pos, 2]
                x_pos = position_list[pos, 0]
                y_pos = position_list[pos, 1]
                if (z_pos < config["hard-limit-z"][0] or z_pos > config["hard-limit-z"][1] 
                    or x_pos < config["hard-limit-x"][0] or x_pos > config["hard-limit-x"][1]
                    or y_pos < config["hard-limit-y"][0] or y_pos > config["hard-limit-y"])[1]:
                    print('position out of range')
                    break
                core.set_position(z_pos)
                core.set_xy_position(x_pos, y_pos)
                xy_device = core.get_xy_stage_device()
                z_device = core.get_focus_device()
                core.wait_for_device(xy_device)
                core.wait_for_device(z_device)
                use_autofocus = ((pos % config["autofocus-speed"] == 0) or first_tile)
                
                if focus_dive and mag=='4x':
                    if use_autofocus:
                        if redive_flag:
                            pos_z, pixels, bg_flag = autofocus(config, core, mag='4x', rgb=True, search_range=1000, steps=5, snap=False)
                            if not bg_flag:
                                first_tile = False
                                pos_z, pixels, bg_flag = autofocus(config, core, mag='4x', rgb=True, search_range=200, steps=5, snap=True)
                        else:
                            pos_z, pixels, bg_flag = autofocus(config, core, mag='4x', rgb=True, search_range=200, steps=5, snap=True)
                        record_z.append(pos_z)
                    else:
                        short_dist = 9999999
                        for k in range(len(record_z)):
                            dist = math.sqrt((x_pos-position_list[k, 0])**2+(y_pos-position_list[k, 1])**2)
                            if dist < short_dist:
                                short_dist = dist
                                pos_z = record_z[k]
                        if pos_z < config["hard-limit-z"][0] or pos_z > config["hard-limit-z"][1]:
                            print('position out of range')
                            break
                        core.set_position(pos_z)
                        core.wait_for_device(z_device)
                        pixels = snap_image(core, rgb=True, flip_channel=True)
                    z_positions[pos] = pos_z              
                if focus_dive and mag=='20x':
                    if use_autofocus:
                        if True:
                            pos_z, pixels, bg_flag = autofocus(config, core, mag='20x', rgb=True, search_range=150, steps=5, check_background=True, snap=False)
                            if not bg_flag:
                                first_tile = False
                                pos_z, _, _ = autofocus(config, core, mag='20x', rgb=True, search_range=25, steps=5, check_background=False, snap=False)
                                pos_z, pixels, _ = autofocus(config, core, mag='20x', rgb=True, search_range=5, steps=5, check_background=False, snap=True)
                        record_z.append(pos_z)
                    else:
                        short_dist = 9999999
                        for k in range(len(record_z)):
                            dist = math.sqrt((x_pos-position_list[k, 0])**2+(y_pos-position_list[k, 1])**2)
                            if dist < short_dist:
                                short_dist = dist
                                pos_z = record_z[k]
                        if pos_z < config["hard-limit-z"][0] or pos_z > config["hard-limit-z"][1]:
                            print('position out of range')
                            break
                        core.set_position(pos_z)
                        core.wait_for_device(z_device)
                        pixels = snap_image(core, rgb=True, flip_channel=True)
#                         pos_z, _, _ = autofocus(config, core, mag='20x', rgb=True, search_range=50, steps=5, check_background=False, snap=True)
#                         pos_z, pixels, _ = autofocus(config, core, mag='20x', rgb=True, search_range=5, steps=5, check_background=False, snap=True)
                    z_positions[pos] = pos_z
                else:
                    pixels = snap_image(core, rgb=True, flip_channel=True)
                pixels = img_as_float(pixels)   
                
                if estimate_background:
                    if focus_dive and use_autofocus:
                        bg_flag = bg_flag
                    elif not use_autofocus or not focus_dive:
                        bg_flag = is_background(pixels)
                    if bg_flag:
                        print(' (background tile)')
                        redive_flag=True
                        sum_img = sum_img + pixels
                        sum_count = sum_count + 1
                    else:
                        redive_flag=False  
                if background_image is not None:
                    pixels = white_balance(pixels, background_image)
                    pixels = flat_field(pixels, bg_img)
                show.set_data(pixels)
                display.display(plt.gcf())
                display.clear_output(wait=True)
                io.imsave(acq_path+'/{}-{}.tiff'.format(pos, bg_flag), img_as_ubyte(pixels))
                tile_count = tile_count + 1
                sys.stdout.write('\r {}/{} tiles done'.format(tile_count, position_list.shape[0]))
                    
        if position_list.shape[1] == 2:
            tile_count = 0
            core.set_focus_device(config["focus-device"])
            z_positions=np.ones(position_list.shape[0]) * core.get_position()
            autofocus_count = 0
            for pos in range(position_list.shape[0]):
                x_pos = position_list[pos, 0]
                y_pos = position_list[pos, 1]
                if ( x_pos < config["hard-limit-x"][0] or x_pos > config["hard-limit-x"][1]
                    or y_pos < config["hard-limit-y"][0] or y_pos > config["hard-limit-y"][1]):
                    print('position out of range')
                    break
                xy_device = core.get_xy_stage_device()
                z_device = core.get_focus_device()
                core.set_xy_position(x_pos, y_pos)
                core.wait_for_device(xy_device)
                use_autofocus = ((pos % config["autofocus-speed"] == 0) or first_tile)
                
                if focus_dive and mag=='4x':
                    if use_autofocus:
                        if redive_flag:
                            pos_z, pixels, bg_flag = autofocus(config, core, mag='4x', rgb=True, search_range=1000, steps=5, snap=False)
                            if not bg_flag:
                                first_tile = False
                                pos_z, pixels, bg_flag = autofocus(config, core, mag='4x', rgb=True, search_range=200, steps=5, snap=True)
                        else:
                            pos_z, pixels, bg_flag = autofocus(config, core, mag='4x', rgb=True, search_range=200, steps=5, snap=True)
                        record_z.append(pos_z)
                    else:
                        short_dist = 9999999
                        for k in range(len(record_z)):
                            dist = math.sqrt((x_pos-position_list[k, 0])**2+(y_pos-position_list[k, 1])**2)
                            if dist < short_dist:
                                short_dist = dist
                                pos_z = record_z[k]
                        if pos_z < config["hard-limit-z"][0] or pos_z > config["hard-limit-z"][1]:
                            print('position out of range')
                            break
                        core.set_position(pos_z)
                        core.wait_for_device(z_device)
                        pixels = snap_image(core, rgb=True, flip_channel=True)
                    z_positions[pos] = pos_z              
                if focus_dive and mag=='20x':
                    if use_autofocus:
                        if True:
                            pos_z, pixels, bg_flag = autofocus(config, core, mag='20x', rgb=True, search_range=150, steps=5, check_background=True, snap=False)
                            if not bg_flag:
                                first_tile = False
                                pos_z, _, _ = autofocus(config, core, mag='20x', rgb=True, search_range=25, steps=5, check_background=False, snap=False)
                                pos_z, pixels, _ = autofocus(config, core, mag='20x', rgb=True, search_range=5, steps=5, check_background=False, snap=True)
                        record_z.append(pos_z)
                    else:
                        short_dist = 9999999
                        for k in range(len(record_z)):
                            dist = math.sqrt((x_pos-position_list[k, 0])**2+(y_pos-position_list[k, 1])**2)
                            if dist < short_dist:
                                short_dist = dist
                                pos_z = record_z[k]
                        if pos_z < config["hard-limit-z"][0] or pos_z > config["hard-limit-z"][1]:
                            print('position out of range')
                            break
                        core.set_position(pos_z)
                        core.wait_for_device(z_device)
                        pixels = snap_image(core, rgb=True, flip_channel=True)
                    z_positions[pos] = pos_z
                else:
                    pixels = snap_image(core, rgb=True, flip_channel=True)
                pixels = img_as_float(pixels)                   
                
                if estimate_background:
                    if focus_dive and use_autofocus:
                        bg_flag = bg_flag
                    elif not use_autofocus or not focus_dive:
                        bg_flag = is_background(pixels)
                        print('hard check')
                    if bg_flag:
                        print(' (background tile)')
                        redive_flag=True
                        sum_img = sum_img + pixels
                        sum_count = sum_count + 1
                    else:
                        redive_flag=False                
                if background_image is not None:
                    pixels = white_balance(config, pixels, background_image)
                    pixels = flat_field(pixels, bg_img)
                show.set_data(pixels)
                display.display(plt.gcf())
                display.clear_output(wait=True)
                io.imsave(acq_path+'/{}-{}.tiff'.format(pos, bg_flag), img_as_ubyte(pixels))
                tile_count = tile_count + 1
                sys.stdout.write('\r {}/{} tiles done'.format(tile_count, position_list.shape[0]))
        returns = []
        if estimate_background:
            returns.append((sum_img / sum_count))
            io.imsave(acq_path+'/bg_img.tiff', img_as_ubyte(np.squeeze(sum_img / sum_count)))
        if focus_dive:
            z_positions = z_positions.reshape(position_list.shape[0], 1)
            returns.append(z_positions)
        return tuple(returns)

def autofocus(config, core, method='edge', mag='4x', rgb=True, search_range=45, steps=5, snap=True, crop_ratio=1.0, flip_channel=True, check_background=True, offset=0):
    if mag=='4x':
        drift_limit = config["Z-stage-4x"]
    if mag=='20x':
        drift_limit = config["Z-stage-20x"]
    core.set_focus_device(config["focus-device"])   
    current_z = core.get_position()
    interval_z = search_range/steps
    scores = []
    positions = []
    count = 0
    for step in range(-int(np.floor(steps/2)), int(np.ceil(steps/2))):
        position_z = step * interval_z + current_z
        if position_z < config["hard-limit-z"][0] or position_z > config["hard-limit-z"][1]:
            print("z-stage out of range, new focus discarded")
            break
        core.set_position(position_z)
        core.wait_for_system()
        count = count + 1
        pixels = snap_image(core, rgb=rgb, flip_channel=True)
        if check_background and step==-int(np.floor(steps/2)):
            bg_flag = is_background(pixels)
            if bg_flag:
                core.set_position(current_z)
                core.wait_for_system()
                print("Is background")
                return current_z, pixels, bg_flag
        img_gray = color.rgb2gray(pixels)
        sys.stdout.write("\r Diving focus at " + str(step))
        if method == 'entropy':
            score = shannon_entropy(img_gray)
        if method == 'edge':
            score = np.mean(sobel(img_gray))
        scores.append(score)
        positions.append(position_z)
    scores_array = np.asarray(scores)
    positions_array = np.asarray(positions) 
    new_length = len(positions) * 100
    new_x = np.linspace(positions_array.min(), positions_array.max(), new_length)
    new_y = sp.interpolate.interp1d(positions_array, scores_array, kind='cubic')(new_x)
    idx = np.argmax(new_y)
    focus_z = new_x[idx]
    if focus_z < config["hard-limit-z"][0] or focus_z > config["hard-limit-z"][1]:
        print("z-stage out of range, new focus discarded")
        focus_z = position_z
    if np.abs(focus_z-drift_limit) > 1000:
        print("z-stage out of range, reset focus")
        focus_z = drift_limit
        core.set_position(drift_limit)
        core.wait_for_system()
    else:
        core.set_position(focus_z)
        core.wait_for_system()
    if snap:
        pixels = snap_image(core, rgb=rgb, flip_channel=True)
        return focus_z+offset, pixels, False
    else:
        return focus_z+offset, None, False    

print("System configured!")
# Out:
# System configured!

# %% [markdown]
# ## 2. Acquisition hardware configuration
# Edit user configuration. After editing, click blank space in front of the section and hit Shift+Return, or click the "run the selected cells and advance" botton in the top menu.

# %%
user_config = {
    
    ### User configuration ###
    
    # Quick configuration group for LSM
    "exposure-level" : 'mid',
    # 'low'     -> scan rate: '500000.0000', pockel cell gain: 0.3, PMT gain: 0.35
    # 'mid'     -> scan rate: '400000.0000', pockel cell gain: 0.4, PMT gain: 0.4
    # 'high'    -> scan rate: '250000.0000', pockel cell gain: 0.425, PMT gain: 0.425
    # 'extreme' -> scan rate: '200000.0000', pockel cell gain: 0.45, PMT gain: 0.45
    
    "snr-level" : 'low',
    # Estimiated correction according to sample SNR level. Available value: 'low', 'mid', 'high'
    
    "autofocus-speed" : 3,
    # Speed of software autofocus, integer: 1~5. Bigger value leads to faster brightfield scan but potentially lower autofocus performance
       
    "lsm-resolution" : 512, 
    # LSM scan resolution, available resolution: 256, 512, 1024
    
    "lsm-bin-factor" : 1,
    # LSM scan pixel average factor, positive integer
    
    "lsm-scan-rate" : '400000.0000', 
    # LSM scan rate, available value (string): '125000.0000', '200000.0000', '250000.0000','400000.0000', '500000.0000', '625000.0000', '1000000.0000'
    
    "lsm-pc-power" : 0.4, 
    # LSM pockel cell gain, float point value: 0.0 ~ 1.0
    
    "lsm-pmt-gain" : 0.4,
    # LSM PMT gain, float point value: 0.0 ~ 1.0
    
    "slide-box" : (-2000, -1000, 30000.0, 21000.0), 
    # Pre-define scan area (read out values from the stage): (start x stage position, start y stage position, end x stage position, end y stage position)
    
    "enhancement-type" : None,
    # Runtime enhancement method, available value (string or None): 'Self', 'Supervised', None
    
     "classifier" : None,
    # Automatic target detection model, available value (string or None): 'MIL', 'Supervised', None 
    
    "classifier-backbone" : "ResNet18",
    # Backbone for CNN model, available value (string): 'ResNet18', 'ResNet34' 
    
    "classifier-num-class" : 2,
    # Number of class for the detector, non-zero integer
    
    "mil-classifier-thresh" : 2,
    # Threshold for MIL classifier. Obtained from training.
    
    "slide-type" : "TMA",
    # Type of image the inference is applied, available value (string): "TMA", "slide"
    
    "gpu" : False,
    # Is GPU available? Available value (boolean): True, False       
}

# %% [markdown]
# ### Generate acquisition configuration
# Run the below section. Wait for message containing the configuration specs.

# %%
hard_config = {
    ### Hard configuration, 
    "pixel-size-bf-20x" : 0.222, # 0.222 micron/pixel at (1392, 1040)
    "pixel-size-bf-4x" : 1.105, # 1.305 micron/pixel at (1392, 1040)
    "pixel-size-shg-base" : 0.509, # 0.509 micron/pixel at 256
    "pixel-size-shg" : 0.509,
    "camera-resolution" : (1392, 1040), # (width, height)
    "lsm-resolution-base" : (512, 512),
    "slide-size" : (35000.0, 20000.0), # (width, height) (70000, -20000)
    "Z-stage-20x" : -6930, # -6930 + 290
    "Z-stage-laser" : -6640, #-6640 
    "Z-stage-4x" : 3570, # -2300
    "F-stage-20x" : -15300, # 11000
    "F-stage-laser" : -18500, # -17500
    "F-stage-4x" : -1000,
    "hard-limit-z" : (-7700.0, 17000.0),
    "hard-limit-x" : (-4000.0, 40000.0),
    "hard-limit-y" : (-4000, 24000.0),
    "hard-limit-f" : (-19000, 0),
    "20x-bf-offset" : (-600, 10), # 4x + this value to 20x // (-590, 74)
    "shg-offset" : (-580, -280), # 4x + this value to shg // (-580, -172)
    "led-4x" : 4,
    "led-20x" : 5,
    "focus-device" : 'ZStage:Z:32',
    "condensor-device" : 'ZStage:F:32',
    "led-device" : ('LED-Dev1ao0', 'Voltage'),
    "obj-device" : ('Turret:O:35', 'Label'),
}
config = {**user_config, **hard_config}
config = config_sys(config)
print("Configuration specs:")
config
# Out:
# Configuration specs:
# {'exposure-level': 'mid',
#  'snr-level': 'low',
#  'autofocus-speed': 3,
#  'lsm-resolution': 256,
#  'lsm-bin-factor': 1,
#  'lsm-scan-rate': '400000.0000',
#  'lsm-pc-power': 0.4,
#  'lsm-pmt-gain': 0.4,
#  'slide-box': (-2000, -1000, 30000.0, 21000.0),
#  'enhancement-type': None,
#  'classifier': None,
#  'classifier-backbone': 'ResNet18',
#  'classifier-num-class': 2,
#  'mil-classifier-thresh': 2,
#  'slide-type': 'TMA',
#  'gpu': False,
#  'pixel-size-bf-20x': 0.222,
#  'pixel-size-bf-4x': 1.105,
#  'pixel-size-shg-base': 0.509,
#  'pixel-size-shg': 0.509,
#  'camera-resolution': (1392, 1040),
#  'lsm-resolution-base': (512, 512),
#  'slide-size': (35000.0, 20000.0),
#  'Z-stage-20x': -6930,
#  'Z-stage-laser': -6640,
#  'Z-stage-4x': 3570,
#  'F-stage-20x': -15300,
#  'F-stage-laser': -18500,
#  'F-stage-4x': -1000,
#  'hard-limit-z': (-7700.0, 17000.0),
#  'hard-limit-x': (-4000.0, 40000.0),
#  'hard-limit-y': (-4000, 24000.0),
#  'hard-limit-f': (-19000, 0),
#  '20x-bf-offset': (-600, 10),
#  'shg-offset': (-580, -280),
#  'led-4x': 4,
#  'led-20x': 5,
#  'focus-device': 'ZStage:Z:32',
#  'condensor-device': 'ZStage:F:32',
#  'led-device': ('LED-Dev1ao0', 'Voltage'),
#  'obj-device': ('Turret:O:35', 'Label')}

# %% [markdown]
# ## 3. Configure Pycro-Manager and PyImageJ
# Make sure Micro-Manager and OpenScan is running appropriately. Run the below section. Wait for message "Succeeded!". Run only once, unless the notebook or Micro-Manager had restarted.

# %%
bridge = Bridge()
core = bridge.get_core()
studio = bridge.get_studio()
ij = imagej.init('fiji\\fiji\\Fiji.app')
core.set_timeout_ms(20000)
print("Succeeded!")
# Out:
# Succeeded!

# %% [markdown]
# ## 4. Configure acquistion parameters
# Enter values and run the below section.

# %%
save_path = 'data/acquisition'
# Data save path, relative path by default

acq_name = 'HPan-Ade170Sur-101-test-v1'
# Acquisition name

# %% [markdown]
# ## 5. Brighfield acquisition at 4x
# Run the below section. Wait for the "4x brighfield acquisition done!" message.

# %%
# 4x acqusition
# save configuration files
os.makedirs('acquisition-configs', exist_ok=True)
with open(os.path.join('acquisition-configs', acq_name+'.json'), 'w') as fp:
    json.dump(config, fp)
# start acquisition
position_list = generate_grid(config, mag='4x')
acq_name_4x = acq_name + '-4x-bf'
switch_objective(config, core, '4x')
switch_mod(config, core, mod='bf')
returns = whole_slide_scan(config, core=core, save_path=save_path, acq_name=acq_name_4x, position_list=position_list.reshape(position_list.shape[0]*position_list.shape[1], -1), mda=False, estimate_background=True, focus_dive=True)
stitching(config, ij, save_path=save_path, acq_name=acq_name_4x, mda=False, position_list=position_list.reshape(position_list.shape[0]*position_list.shape[1], -1), flip_y=True, correction=True, background_image=returns[0])
export_slide(mag='4x')
pd_arr = pd.DataFrame(returns[1])
pd_arr.to_csv(os.path.join(save_path, acq_name_4x+'-z_pos.csv'), index=False)
pd_arr_r = pd.read_csv(os.path.join(save_path, acq_name_4x+'-z_pos.csv'))
z_pos_4x = np.array(pd_arr_r)
print('\r, 4x brighfield acquisition done!')

# %% [markdown]
# ## 6. Use machine learning detection
# Run the below section. Wait for the detection map to be printed.

# %%
### Machine learning detection model
predictor = config["predictor"]
os.makedirs('data-predictor', exist_ok=True)
shutil.copyfile(os.path.join('data', 'slides', '4x', acq_name_4x+'.ome.tif'), os.path.join('data-predictor', acq_name_4x+'.ome.tif'))
subprocess.run(["python", "patch_extraction.py", "-s", config["slide-type"], "-f", "tif", "-p", "1"], shell=True)
slides = glob.glob(os.path.join('data-predictor', '*.tif')) + glob.glob(os.path.join('data-predictor', '*.jpg'))
pos = []
image_format = slides[0].split('.')[-1]
for slide in slides:
    slide_name = slide.split(os.sep)[-1].replace('.'+image_format, '')
    fields = glob.glob(os.path.join('data-predictor', slide_name, '*.tif'))
    if config["classifier"] == "Supervised":
        for field in fields:
            pos_x = int(field.split('x=')[1].split(',')[0])
            pos_y = int(field.split('y=')[1].split(',')[0])
            img = io.imread(field)
            prediction = predictor.compute(img)
            c = np.argmax(prediction)
            pos.append([int(pos_x/224), int(pos_y/224), c])
    if config["classifier"] == "MIL":
        prediction_bag, prediction_patch = predictor.compute(fields)
        if prediction_bag:
            for i in range(len(fields)):
                pos_x = int(fields[i].split('x=')[1].split(',')[0])
                pos_y = int(fields[i].split('y=')[1].split(',')[0])
                pos.append([int(pos_x/224), int(pos_y/224), prediction_patch[i]])
pos_arr = np.vstack(pos)
w = np.max(pos_arr, 0)[0]+1
h = np.max(pos_arr, 0)[1]+1
cmap = np.zeros((h ,w))
for p in pos:
    cmap[p[1], p[0]] = p[2]
if config["slide-type"] == "slide":
    cmap_p = morphology.remove_small_objects(img_as_bool(cmap), min_size=6)
    cmap_p = morphology.remove_small_holes(cmap_p, area_threshold=8)
if config["slide-type"] == "TMA":
    cmap_p = cmap
plt.imshow(cmap_p)
os.makedirs(os.path.join('qupath-projects', 'predictions'), exist_ok=True)
io.imsave(os.path.join('qupath-projects', 'predictions', slide_name+'-cmap.bmp'), img_as_ubyte(cmap_p))
# resample 20x bf
field_4x = 224 * config["pixel-size-bf-4x"]
field_w_20x = config["camera-resolution"][0] * config["pixel-size-bf-20x"] * 0.9
field_h_20x = config["camera-resolution"][1] * config["pixel-size-bf-20x"] * 0.9
rw = int(w * (field_4x/field_w_20x))
rh = int(h * (field_4x/field_h_20x))
cmap_r = transform.resize(cmap_p, (rh, rw), order=1, mode='symmetric')
thresh = threshold_mean(cmap_r)*0.5
cmap_r = cmap_r >= thresh
ps_pos = np.where(cmap_r==1)
pos_20x_df = pd.DataFrame({
    'x_pos' : ps_pos[1]*field_w_20x/config["pixel-size-bf-4x"],
    'y_pos' : ps_pos[0]*field_h_20x/config["pixel-size-bf-4x"]}
)
# resample shg
field_mp = 256 * config["pixel-size-shg-base"] * 0.9
rw = int(w * (field_4x/field_mp))
rh = int(h * (field_4x/field_mp))
cmap_r = transform.resize(cmap_p, (rh, rw), order=1, mode='symmetric')
thresh = threshold_mean(cmap_r)*0.5
cmap_r = cmap_r >= thresh
ps_pos = np.where(cmap_r==1)
pos_mp_df = pd.DataFrame({
    'x_pos' : ps_pos[1]*field_mp/config["pixel-size-bf-4x"],
    'y_pos' : ps_pos[0]*field_mp/config["pixel-size-bf-4x"]}
)
if image_format == 'tif':
    pos_mp_df.to_csv(os.path.join('qupath-projects', 'predictions', 'mp-'+slide_name+'.tif.csv'), index=False)
    pos_mp_df.to_csv(os.path.join('qupath-projects', 'mp-tiles', slide_name+'.tif.csv'), index=False)
    pos_20x_df.to_csv(os.path.join('qupath-projects', 'predictions', '20x-'+slide_name+'.tif.csv'), index=False)
    pos_20x_df.to_csv(os.path.join('qupath-projects', '20x-tiles', slide_name+'.tif.csv'), index=False)
if image_format == 'jpg':
    pos_mp_df.to_csv(os.path.join('qupath-projects', 'predictions', 'mp-'+slide_name+'.csv'), index=False)
    pos_mp_df.to_csv(os.path.join('qupath-projects', 'mp-tiles', slide_name+'.csv'), index=False)
    pos_20x_df.to_csv(os.path.join('qupath-projects', 'predictions', '20x-'+slide_name+'.csv'), index=False)
    pos_20x_df.to_csv(os.path.join('qupath-projects', '20x-tiles', slide_name+'.csv'), index=False)

# %% [markdown]
# ## 7. Brighfield acquisition at 20x
# Make sure 20x brightfield annotation files are generated appropriately. Run the below section. Wait for the "20x brighfield acquisition done!" message.

# %%
acq_name_20x = '-20x-'
### enter the 20x acquisition name appended to the original acquisition name

# %%
# batch 20x acquisition
switch_objective(config, core, '20x')
switch_mod(config, core, 'bf')
slide_name = acq_name
pd_arr_r = pd.read_csv(os.path.join(save_path, acq_name_4x+'-z_pos.csv'))
z_pos_4x = np.array(pd_arr_r)
position_list_z = z_pos_4x
position_list = generate_grid(config, mag='4x')
position_list_xyz = np.concatenate((position_list, position_list_z.reshape((position_list.shape[0], position_list.shape[1], 1))), 2)
position_lists_20x, annotation_names = annotations_positionlist(config, image_name=acq_name_4x, out_mag='20x')
return_20x_list = []
for idx, roi in enumerate(position_lists_20x):
    current_acq_name = slide_name + acq_name_20x + annotation_names[idx]
    sampled_pos_xyz = resample_z_pos(config, mag='20x', xy_pos=roi, xyz_pos_list_4x=position_list_xyz)
    if idx==0:
        returns_20x = whole_slide_scan(config, core=core, save_path=save_path, acq_name=current_acq_name, mag='20x', position_list=sampled_pos_xyz, mda=False, estimate_background=True, focus_dive=True)
        stitching(config, ij, save_path=save_path, acq_name=current_acq_name, mag='20x', mda=False, position_list=sampled_pos_xyz, flip_y=True, correction=True, background_image=returns_20x[0])
        bg_img = returns_20x[0]
    else:
        returns_20x = whole_slide_scan(config, core=core, save_path=save_path, acq_name=current_acq_name, mag='20x', position_list=sampled_pos_xyz, mda=False, estimate_background=False, background_image=bg_img, focus_dive=True)
        stitching(config, ij, save_path=save_path, acq_name=current_acq_name, mag='20x', mda=False, position_list=sampled_pos_xyz, flip_y=True, correction=False)
    export_slide(mag='20x', remove_file=True)
    return_20x_list.append(returns_20x[-1]) ### store focus map
    np.save(os.path.join(save_path, slide_name +'-20x'+'-z_pos.npy'), return_20x_list, allow_pickle=True)
    print('Object: {}/{}'.format(idx+1, len(position_lists_20x)))
print('\r, 20x brighfield acquisition done!')

# %% [markdown]
# ## 8. SHG acquisition at 20x
# Make sure SHG annotation files are generated appropriately. Run the below section. Wait for the "20x brighfield acquisition done!" message.

# %%
acq_name_lsm = '-lsm-'
### enter the LSM acquisition name appended to the original acquisition name

# %%
# batch shg acquisition use all map
acq_name_4x = acq_name + '-4x-bf'
switch_objective(config, core, '20x')
switch_mod(config, core, 'shg')
save_path = 'data/acquisition'
slide_name = acq_name
position_lists_mp, annotation_mp = annotations_positionlist(config, image_name=acq_name_4x, out_mag='mp')
position_lists_20x, annotation_names = annotations_positionlist(config, image_name=acq_name_4x, out_mag='20x')
return_20x_list = np.load(os.path.join(save_path, slide_name+'-20x'+'-z_pos.npy'), allow_pickle=True).tolist()
return_20x_list = np.vstack(return_20x_list)
position_lists_20x =  np.vstack(position_lists_20x)
map_xyz_20x = np.concatenate((position_lists_20x[:6434, :], return_20x_list.reshape((return_20x_list.shape[0], 1))), 1)
for idx, roi in enumerate(position_lists_mp):
    if idx<30:
        continue
        print('\n Unmatched annotation! \n')
    current_acq_name = slide_name + acq_name_lsm + annotation_mp[idx]
    sampled_pos_xyz_mp = resample_z_pos(config, mag='mp', xy_pos=roi, xyz_pos_list_20x=map_xyz_20x)
    whole_slide_scan(config, core=core, save_path=save_path, acq_name=current_acq_name, position_list=sampled_pos_xyz_mp, mda=True, z_stack=True, sample_depth=24, z_step=6, estimate_background=False, focus_dive=False)
    stitching(config, ij, save_path=save_path, acq_name=current_acq_name, mag='mp', mda=True, z_stack=True, position_list=sampled_pos_xyz_mp, flip_y=False, rotate=270, correction=None)
    export_slide(mag='mp')
print('\r, SHG acquisition done!')
# Out:
# Imaging mode set as SHG
# Dataset opened
#  Processing tiles: 298/298
#  stitching, please wait...
# [java.lang.Enum.toString] Stitching internal version: 1.2[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\0.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\0.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (3493 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\1.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\1.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (534 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\2.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\2.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (141 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\3.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\3.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (152 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\4.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\4.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (128 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\5.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\5.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (148 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\6.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\6.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (149 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\7.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\7.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (159 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\8.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\8.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (164 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\9.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\9.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (157 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\10.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\10.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (433 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\11.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\11.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (126 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\12.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\12.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (793 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\13.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\13.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (136 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\14.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\14.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (127 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\15.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\15.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (130 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\16.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\16.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (132 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\17.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\17.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (135 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\18.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\18.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (138 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\19.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\19.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (183 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\20.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\20.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (125 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\21.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\21.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (129 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\22.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\22.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (126 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\23.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\23.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (122 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\24.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\24.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (127 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\25.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\25.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (132 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\26.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\26.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (134 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\27.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\27.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (173 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\28.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\28.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (124 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\29.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\29.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (131 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\30.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\30.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (129 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\31.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\31.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (124 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\32.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\32.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (130 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\33.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\33.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (132 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\34.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\34.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (124 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\35.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\35.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (326 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\36.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\36.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (125 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\37.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\37.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (125 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\38.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\38.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (130 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\39.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\39.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (121 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\40.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\40.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (119 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\41.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\41.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (122 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\42.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\42.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (125 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\43.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\43.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (159 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\44.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\44.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (122 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\45.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\45.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (135 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\46.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\46.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (132 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\47.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\47.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (120 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\48.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\48.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (123 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\49.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\49.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# [java.lang.Enum.toString] 512x512x5px, channels=1, timepoints=1 (154 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Loading: F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\50.tiff ... [java.lang.Enum.toString]
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] TiffDelegateReader initializing F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\tiles\HPan-Ade170Sur-101-test-v1-lsm-512-aug--A-1\50.tiff
# [java.lang.Enum.toString] Reading IFDs
# [java.lang.Enum.toString] Populating metadata
# [java.lang.Enum.toString] Checking comment style
# [java.lang.Enum.toString] Populating OME metadata
# [java.lang.Enum.toString] dimension order is not certain, assuming XYZ instead of XYT[java.lang.Enum.toString]
# ...
# [java.lang.Enum.toString] 52.tiff: [1,3](67566.0,127.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 53.tiff: [1,3](67566.0,578.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 54.tiff: [1,3](67566.0,1030.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 55.tiff: [1,3](67566.0,1482.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 56.tiff: [1,3](67566.0,1934.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 57.tiff: [1,3](67566.0,2386.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 58.tiff: [1,3](67566.0,2838.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 59.tiff: [1,3](67566.0,3289.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 60.tiff: [1,3](67566.0,3741.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 61.tiff: [1,3](68018.0,-2132.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 62.tiff: [1,3](68018.0,-1680.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 63.tiff: [1,3](68018.0,-1228.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 64.tiff: [1,3](68018.0,-776.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 65.tiff: [1,3](68018.0,-324.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 66.tiff: [1,3](68018.0,127.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 67.tiff: [1,3](68018.0,578.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 68.tiff: [1,3](68018.0,1030.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 69.tiff: [1,3](68018.0,1482.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 70.tiff: [1,3](68018.0,1934.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 71.tiff: [1,3](68018.0,2386.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 72.tiff: [1,3](68018.0,2838.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 73.tiff: [1,3](68018.0,3289.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 74.tiff: [1,3](68018.0,3741.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 75.tiff: [1,3](68470.0,-2132.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 76.tiff: [1,3](68470.0,-1680.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 77.tiff: [1,3](68470.0,-1228.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 78.tiff: [1,3](68470.0,-776.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 79.tiff: [1,3](68470.0,-324.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 80.tiff: [1,3](68470.0,127.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 81.tiff: [1,3](68470.0,578.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 82.tiff: [1,3](68470.0,1030.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 83.tiff: [1,3](68470.0,1482.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 84.tiff: [1,3](68470.0,1934.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 85.tiff: [1,3](68470.0,2386.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 86.tiff: [1,3](68470.0,2838.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 87.tiff: [1,3](68470.0,3289.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 88.tiff: [1,3](68470.0,3741.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 89.tiff: [1,3](68922.0,-2132.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 90.tiff: [1,3](68922.0,-1680.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 91.tiff: [1,3](68922.0,-1228.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 92.tiff: [1,3](68922.0,-776.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 93.tiff: [1,3](68922.0,-324.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 94.tiff: [1,3](68922.0,127.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 95.tiff: [1,3](68922.0,578.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 96.tiff: [1,3](68922.0,1030.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 97.tiff: [1,3](68922.0,1482.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 98.tiff: [1,3](68922.0,1934.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 99.tiff: [1,3](68922.0,2386.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 100.tiff: [1,3](68922.0,2838.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 101.tiff: [1,3](68922.0,3289.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 102.tiff: [1,3](68922.0,3741.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 103.tiff: [1,3](69374.0,-2132.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 104.tiff: [1,3](69374.0,-1680.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 105.tiff: [1,3](69374.0,-1228.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 106.tiff: [1,3](69374.0,-776.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 107.tiff: [1,3](69374.0,-324.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 108.tiff: [1,3](69374.0,127.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 109.tiff: [1,3](69374.0,578.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 110.tiff: [1,3](69374.0,1030.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 111.tiff: [1,3](69374.0,1482.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 112.tiff: [1,3](69374.0,1934.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 113.tiff: [1,3](69374.0,2386.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 114.tiff: [1,3](69374.0,2838.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 115.tiff: [1,3](69374.0,3289.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 116.tiff: [1,3](69374.0,3741.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 117.tiff: [1,3](69825.0,-2132.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 118.tiff: [1,3](69825.0,-1680.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 119.tiff: [1,3](69825.0,-1228.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 120.tiff: [1,3](69825.0,-776.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 121.tiff: [1,3](69825.0,-324.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 122.tiff: [1,3](69825.0,127.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 123.tiff: [1,3](69825.0,578.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 124.tiff: [1,3](69825.0,1030.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 125.tiff: [1,3](69825.0,1482.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 126.tiff: [1,3](69825.0,1934.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 127.tiff: [1,3](69825.0,2386.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 128.tiff: [1,3](69825.0,2838.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 129.tiff: [1,3](69825.0,3289.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 130.tiff: [1,3](69825.0,3741.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 131.tiff: [1,3](70277.0,-2132.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 132.tiff: [1,3](70277.0,-1680.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 133.tiff: [1,3](70277.0,-1228.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 134.tiff: [1,3](70277.0,-776.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 135.tiff: [1,3](70277.0,-324.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 136.tiff: [1,3](70277.0,127.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 137.tiff: [1,3](70277.0,578.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 138.tiff: [1,3](70277.0,1030.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 139.tiff: [1,3](70277.0,1482.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 140.tiff: [1,3](70277.0,1934.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 141.tiff: [1,3](70277.0,2386.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 142.tiff: [1,3](70277.0,2838.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 143.tiff: [1,3](70277.0,3289.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 144.tiff: [1,3](70729.0,-1680.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 145.tiff: [1,3](70729.0,-1228.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 146.tiff: [1,3](70729.0,-776.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 147.tiff: [1,3](70729.0,-324.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 148.tiff: [1,3](70729.0,127.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 149.tiff: [1,3](70729.0,578.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 150.tiff: [1,3](70729.0,1030.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 151.tiff: [1,3](70729.0,1482.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 152.tiff: [1,3](70729.0,1934.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 153.tiff: [1,3](70729.0,2386.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 154.tiff: [1,3](70729.0,2838.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 155.tiff: [1,3](70729.0,3289.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 156.tiff: [1,3](71181.0,-1228.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 157.tiff: [1,3](71181.0,-776.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 158.tiff: [1,3](71181.0,-324.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 159.tiff: [1,3](71181.0,127.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 160.tiff: [1,3](71181.0,578.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 161.tiff: [1,3](71181.0,1030.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 162.tiff: [1,3](71181.0,1482.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 163.tiff: [1,3](71181.0,1934.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 164.tiff: [1,3](71181.0,2386.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 165.tiff: [1,3](71181.0,2838.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 166.tiff: [1,3](71633.0,-776.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 167.tiff: [1,3](71633.0,-324.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 168.tiff: [1,3](71633.0,127.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 169.tiff: [1,3](71633.0,578.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 170.tiff: [1,3](71633.0,1030.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 171.tiff: [1,3](71633.0,1482.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] 172.tiff: [1,3](71633.0,1934.0,0.0) 1.7976931348623157E308[java.lang.Enum.toString]
# [java.lang.Enum.toString] Fuse & Write to disk (into directory 'F:\Documents\slide-scanner\smart-wsi-scanner\data\stitching\channel_temp') ...[java.lang.Enum.toString]
# [java.lang.Enum.toString] Finished fusion (21101 ms)[java.lang.Enum.toString]
# [java.lang.Enum.toString] Finished ... (47456 ms)[java.lang.Enum.toString]
# exporting slides, please wait...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-9579e3ef5bbd> in <module>()
#      16     current_acq_name = slide_name + '-lsm-512-aug-' + annotation_mp[idx]
#      17     sampled_pos_xyz_mp = resample_z_pos(config, mag='mp', xy_pos=roi, xyz_pos_list_20x=map_xyz_20x)
# ---> 18     whole_slide_scan(config, core=core, save_path=save_path, acq_name=current_acq_name, position_list=sampled_pos_xyz_mp, mda=True, z_stack=True, sample_depth=24, z_step=6, estimate_background=False, focus_dive=False)
#      19     stitching(config, ij, save_path=save_path, acq_name=current_acq_name, mag='mp', mda=True, z_stack=True, position_list=sampled_pos_xyz_mp, flip_y=False, rotate=270, correction=None)
#      20     export_slide(mag='mp')
#
# <ipython-input-1-b3cce8c8b4fa> in whole_slide_scan(config, core, save_path, acq_name, position_list, mag, mda, z_stack, z_center, sample_depth, z_step, estimate_background, background_image, focus_dive)
#      55                 with Acquisition(save_path, acq_name, lsm_process_fn(config)) as acq:
#      56                     events = multi_d_acquisition_events(xyz_positions=position_list.reshape(-1, 3), z_start=-int(sample_depth/2), z_end=int(sample_depth/2), z_step=z_step)
# ---> 57                     acq.acquire(events)
#      58             else:
#      59                 with Acquisition(save_path, acq_name) as acq:
#
# C:\Users\lociuser\Miniconda3\envs\pyimagej\lib\site-packages\pycromanager\acquire.py in __exit__(self, exc_type, exc_val, exc_tb)
#     415             self._event_queue.put(None)
#     416         # now wait on it to finish
# --> 417         self.await_completion()
#     418
#     419     def get_disk_location(self):
#
# C:\Users\lociuser\Miniconda3\envs\pyimagej\lib\site-packages\pycromanager\acquire.py in await_completion(self)
#     441         """Wait for acquisition to finish and resources to be cleaned up"""
#     442         while not self._remote_acq.is_finished():
# --> 443             time.sleep(0.1)
#     444         self._remote_acq = None
#     445         self._finished = True
#
# KeyboardInterrupt:
